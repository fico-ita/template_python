# %% [markdown]
# #0.Directory Structure Prerequirite

# %% [markdown]
#     po_245_2023_S2_T5/
#     │
#     ├── docs/
#     │   ├── images/
#     │   ├── materials/
#     │   ├── tutorials/
#     │   ├── index.md
#     │   ├── tutorials.md
#     │   ├── how-to-guides.md
#     │   ├── reference.md
#     │   └── explanation.md
#     │
#     ├── fico/
#     │   ├── __init__.py
#     │   └── strategy_meta_labeling_r04.py
#     │
#     ├── dataset/
#     │
#     ├── modules/
#     │
#     └── mkdocs.yml

# %% [markdown]
# #1.Load Data

# %%
from modules.load_data import load_data
dict_data = load_data()
print(dict_data.keys())
# Out:
# dict_keys(['rate', 'sp', 'prices'])

# %%
dict_data['prices']
# Out:
# Ticker           A    AAL    AAP    AAPL    ABBV     ABC   ABMD     ABT  \
# Date
# 2011-06-02   31.43   8.59  55.20   10.50     NaN   33.90  17.81   19.20
# 2011-06-03   30.94   8.38  54.52   10.42     NaN   33.56  17.28   19.14
# 2011-06-06   30.70   8.06  53.72   10.26     NaN   33.65  16.86   19.11
# 2011-06-07   31.12   8.07  53.30   10.08     NaN   34.03  17.10   19.25
# 2011-06-08   31.14   7.79  53.28   10.08     NaN   34.08  17.06   19.31
# ...            ...    ...    ...     ...     ...     ...    ...     ...
# 2023-06-26  118.15  16.44  67.29  185.27  134.95  187.76    NaN  108.51
# 2023-06-27  116.82  17.35  68.32  188.06  132.60  188.78    NaN  107.79
# 2023-06-28  116.15  17.55  68.08  189.25  132.51  189.72    NaN  107.61
# 2023-06-29  117.83  17.60  68.23  189.59  133.23  190.52    NaN  107.66
# 2023-06-30  120.25  17.94  70.30  193.97  134.73  192.43    NaN  109.02
#
# Ticker       ACGL     ACN  ...   XLNX     XOM   XRAY    XRX     XYL     YUM  \
# Date                       ...
# 2011-06-02  11.29   45.41  ...  28.10   50.39  35.05  18.11     NaN   30.96
# 2011-06-03  11.23   44.61  ...  27.21   50.30  34.35  18.02     NaN   30.92
# 2011-06-06  11.18   44.58  ...  27.23   49.75  33.96  17.59     NaN   30.62
# 2011-06-07  11.15   44.97  ...  27.59   49.57  33.85  17.30     NaN   30.77
# 2011-06-08  11.09   44.55  ...  26.91   50.04  33.82  17.04     NaN   30.44
# ...           ...     ...  ...    ...     ...    ...    ...     ...     ...
# 2023-06-26  71.22  297.41  ...    NaN  104.29  39.17  14.03  110.67  134.23
# 2023-06-27  71.14  300.81  ...    NaN  104.55  39.77  14.22  111.61  134.28
# 2023-06-28  71.68  301.72  ...    NaN  105.40  39.44  14.03  110.54  135.16
# 2023-06-29  73.03  308.33  ...    NaN  106.70  39.51  14.85  111.34  137.26
# 2023-06-30  74.85  308.58  ...    NaN  107.25  40.02  14.89  112.62  138.55
#
# Ticker         ZBH    ZBRA   ZION     ZTS
# Date
# 2011-06-02   58.48   42.59  18.68     NaN
# 2011-06-03   58.03   41.61  18.54     NaN
# 2011-06-06   57.41   41.09  17.95     NaN
# 2011-06-07   56.84   41.24  17.65     NaN
# 2011-06-08   55.93   41.21  17.84     NaN
# ...            ...     ...    ...     ...
# 2023-06-26  142.81  273.11  27.08  167.54
# 2023-06-27  144.81  282.81  27.30  170.67
# 2023-06-28  144.00  283.49  27.09  169.10
# 2023-06-29  145.15  288.68  27.28  171.87
# 2023-06-30  145.60  295.83  26.86  172.21
#
# [3040 rows x 743 columns]

# %% [markdown]
# #2.A single day example

# %%
from fico.strategy_meta_labeling_r04 import D_strategy_meta_labeling
Portfolio = D_strategy_meta_labeling(dict_data, t = 2000, size = 10, window_size=500)

# %%
Portfolio
# Out:
#            ticker   weights
# date
# 2019-05-11    ALB  0.101264
# 2019-05-11   REGN  0.101264
# 2019-05-11    MYL  0.101264
# 2019-05-11   BKNG  0.100882
# 2019-05-11    ADI  0.100286
# 2019-05-11    PHM  0.099938
# 2019-05-11    AES  0.099651
# 2019-05-11    PXD  0.098805
# 2019-05-11   WELL  0.098347
# 2019-05-11    FDX  0.098298
